# %% [markdown]
# <a href="https://colab.research.google.com/github/Thaisams/coleta-amostragem-dados-1/blob/main/Coleta_e_amostragem_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = input('Digite o seu nome: ')
idade = input('Digite sua idade: ')
altura = float(input('Digite sua altura: '))

print('Olá, ' + nome)
print('Você tem ' + idade)
print(f'Olá, {nome}, você tem {idade} anos e mede {altura} metros!')
# Out:
# Digite o seu nome: teste
# Digite sua idade: 12
# Digite sua altura: 14.3
# Olá, teste
# Você tem 12
# Olá, teste, você tem 12 anos e mede 14.3 metros!
